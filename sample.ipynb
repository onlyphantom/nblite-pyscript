# %% [markdown]
# # NbLite: Serveless Notebooks on the browser with PyScript
#
# Want to try your own notebook? change the url to point to your notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

rv = np.random.standard_normal(1000)

fig, ax = plt.subplots()
ax.hist(rv, bins=30)
fig

# %% [markdown]
# ## Considerations
#
# - Not all notebooks will run properly, since not every library works with pyodide
# - This project has no affiliation with Binder
